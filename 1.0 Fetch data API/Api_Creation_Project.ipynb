# %%
import pandas as pd
import requests

# %%
response= requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=342fff4bf91a946f37d84ea29d822846')

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg  [18, 80]  278                en
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     133.625
# 1  Spanning the years 1945 to 1955, a chronicle o...     128.403
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False           8.7       26110
# 1  False           8.7       19792

# %%
df=pd.DataFrame(response.json()['results'])[['id', 'release_date','title','vote_average','vote_count','original_language']]

# %%
df.head(5)
# Out:
#     id release_date                     title  vote_average  vote_count  \
# 0  278   1994-09-23  The Shawshank Redemption         8.700       26110
# 1  238   1972-03-14             The Godfather         8.700       19792
# 2  240   1974-12-20     The Godfather Part II         8.600       11954
# 3  424   1993-12-15          Schindler's List         8.567       15361
# 4  389   1957-04-10              12 Angry Men         8.500        8228
#
#   original_language
# 0                en
# 1                en
# 2                en
# 3                en
# 4                en

# %%
df.shape
# Out:
# (20, 6)

# %% [markdown]
# **Now we will fetch all the data**

# %%
df= pd.DataFrame()

# %%
# Create an empty list to store the DataFrames
dfs = []

for i in range(1, 469):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=342fff4bf91a946f37d84ea29d822846&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'release_date','title','vote_average','vote_count','original_language']]
    dfs.append(temp_df)

# Concatenate all DataFrames in the list
df = pd.concat(dfs, ignore_index=True)

# %%
df.shape
# Out:
# (9357, 6)

# %%
df.to_csv('movies_tmdb.csv')
