# %%
import pandas as pd

# %%
df= pd.read_csv('https://github.com/V-Vibee/CampusX-/raw/main/1.1%20Column%20Transformer%20%26%20%20Pipes/covid_toy.csv')

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
y= df['has_covid']
X= df.drop(['has_covid'], axis=1)

# %%
X
# Out:
#     age  gender  fever   cough       city
# 0    60    Male  103.0    Mild    Kolkata
# 1    27    Male  100.0    Mild      Delhi
# 2    42    Male  101.0    Mild      Delhi
# 3    31  Female   98.0    Mild    Kolkata
# 4    65  Female  101.0    Mild     Mumbai
# ..  ...     ...    ...     ...        ...
# 95   12  Female  104.0    Mild  Bangalore
# 96   51  Female  101.0  Strong    Kolkata
# 97   20  Female  101.0    Mild  Bangalore
# 98    5  Female   98.0  Strong     Mumbai
# 99   10  Female   98.0  Strong    Kolkata
#
# [100 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.2, random_state=2529)

# %% [markdown]
# **Mentos Zindagi**

# %% [markdown]
# **Missing Values in Fever column needs to be filled with simple imputer(Mean)**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
transformer= ColumnTransformer(transformers=[
    ('trf1', SimpleImputer(),['fever']),
    ('trf2',OrdinalEncoder(categories=[['Mild', 'Strong']]),['cough']),
    ('trf3', OneHotEncoder(sparse_output= False,drop='first'), ['gender', 'city'])

    ], remainder='passthrough')

# %%
transformer.fit_transform(X_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(X_test).shape
# Out:
# (20, 7)
